# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\Valens\Documents\Python Anaconda\Instacart Basket Analysis'

# %%
df_cust = pd.read_csv(os.path.join(path, '02 Data', 'customers.csv'))

# %%
df_cust.shape
# Out:
# (206209, 10)

# %%
df_cust.tail()
# Out:
#         user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# 206208    80148    Cynthia     Noble  Female        New York   55    4/1/2020
#
#         n_dependants fam_status  income
# 206204             1    married  148828
# 206205             3    married  168639
# 206206             2    married   53374
# 206207             1    married   99799
# 206208             1    married   57095

# %%
df_cust.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %%
df_cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206209 entries, 0 to 206208
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   user_id       206209 non-null  int64
#  1   First Name    194950 non-null  object
#  2   Surnam        206209 non-null  object
#  3   Gender        206209 non-null  object
#  4   STATE         206209 non-null  object
#  5   Age           206209 non-null  int64
#  6   date_joined   206209 non-null  object
#  7   n_dependants  206209 non-null  int64
#  8   fam_status    206209 non-null  object
#  9   income        206209 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 15.7+ MB

# %% [markdown]
# # Question 4

# %%
#Changing the column name from Surnam to Surname
df_cust.rename(columns = {'Surnam' : 'Surname'}, inplace = True)

# %%
#Changing the column name from n_dependants to people_supported_financially
df_cust.rename(columns = {'n_dependants' : 'people_supported_financially'}, inplace = True)

# %%
# changing the user id to string
df_cust['user_id'] = df_cust['user_id'].astype('str')

# %% [markdown]
# # There is no column that I dropped because every column in this table is useful for the analysis

# %% [markdown]
# # Question 5

# %%
# Test column if there is a mix 
for col in df_cust.columns.tolist():
  weird = (df_cust[[col]].applymap(type) != df_cust[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_cust[weird]) > 0:
    print (col)
# Out:
# First Name

# %%
# Changing First name type to string, cause it seems they have problematic column
df_cust['First Name'] = df_cust['First Name'].astype('str')

# %%
#do another test to see if the mix problem has been solve
for col in df_cust.columns.tolist():
  weird = (df_cust[[col]].applymap(type) != df_cust[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_cust[weird]) > 0:
    print (col)

# %% [markdown]
# # from the above it looks the problematic column where there are mix data type is already fixed.

# %%
# checking if there is null column
df_cust.isnull().sum()
# Out:
# user_id                         0
# First Name                      0
# Surname                         0
# Gender                          0
# STATE                           0
# Age                             0
# date_joined                     0
# people_supported_financially    0
# fam_status                      0
# income                          0
# dtype: int64

# %% [markdown]
# # Base on the data above there is no null column

# %%
# checking if there is any duplicate in our table
df_cust_dups = df_cust[df_cust.duplicated()]

# %%
#printing the table
df_cust_dups
# Out:
# Empty DataFrame
# Columns: [user_id, First Name, Surname, Gender, STATE, Age, date_joined, people_supported_financially, fam_status, income]
# Index: []

# %% [markdown]
# # There isn't duplicate data above as well.

# %% [markdown]
# # Question 6

# %%
df_cust.head()
# Out:
#   user_id First Name   Surname  Gender       STATE  Age date_joined  \
# 0   26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1   33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2   65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3  125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4  130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    people_supported_financially fam_status  income
# 0                             3    married  165665
# 1                             0     single   59285
# 2                             2    married   99568
# 3                             0     single   42049
# 4                             1    married   40374

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_with_category_with_flag.pkl'))

# %%
#it turns out I can't merge a column if they have a different data type
df_cust['user_id'] = df_cust['user_id'].astype('int')

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  ...  \
# 0             19     5.8          1987   3139998      138    prior  ...
# 1             19     5.8          1989   1977647      138    prior  ...
# 2             19     5.8         11433    389851      709    prior  ...
# 3             19     5.8         12198    652770      764    prior  ...
# 4             19     5.8         12200   1813452      764    prior  ...
#
#    exists    price_range_loc         busiest_days  busiest_period_of_day  \
# ...

# %%
# dropping _merge and exist, so we could have more rooms to do an indicator in the column
ords_prods_merge = ords_prods_merge.drop(columns = ['eval_set','exists','_merge'])

# %%
ords_prods_merge.head()
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0_y  order_id  user_id  order_number  ...  \
# 0             19     5.8          1987   3139998      138            28  ...
# 1             19     5.8          1989   1977647      138            30  ...
# 2             19     5.8         11433    389851      709             2  ...
# 3             19     5.8         12198    652770      764             1  ...
# 4             19     5.8         12200   1813452      764             3  ...
#
#    reordered    price_range_loc         busiest_days  busiest_period_of_day  \
# ...

# %%
# Merging 2 files together with user id as the key
df_cust_ords_prods_merged = df_cust.merge(ords_prods_merge, on = ['user_id'], indicator = True)

# %%
# Merging 2 files together with user id as the key using outer join
df_cust_ords_prods_merged_outer = df_cust.merge(ords_prods_merge, on = ['user_id'], how ='outer', indicator = 'exists')

# %%
# allowing us to view tha maximum column
pd.options.display.max_columns = None

# %%
df_cust_ords_prods_merged.head()
# Out:
#    user_id First Name   Surname  Gender     STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 1    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 2    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 3    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
# 4    26711    Deborah  Esquivel  Female  Missouri   48    1/1/2017
#
#    people_supported_financially fam_status  income  Unnamed: 0_x  product_id  \
# 0                             3    married  165665           195         196
# 1                             3    married  165665           195         196
# 2                             3    married  165665           195         196
# 3                             3    married  165665          6184        6184
# 4                             3    married  165665          6184        6184
#
#   product_name  aisle_id  department_id  prices  Unnamed: 0_y  order_id  \
# ...

# %%
# trying to see if both have a matching user id
df_cust_ords_prods_merged['_merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
# trying to see if both have a matching user id
df_cust_ords_prods_merged_outer['exists'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: exists, dtype: int64

# %%
# To see the number of row
ords_prods_merge.shape
# Out:
# (32404859, 24)

# %%
# To see the number of row
df_cust.shape
# Out:
# (206209, 10)

# %%
# To see the number of row
df_cust_ords_prods_merged.shape
# Out:
# (32404859, 34)

# %%
df_cust_ords_prods_merged.loc[df_cust_ords_prods_merged['prices']>100,'prices'] = np.nan

# %%
df_cust_ords_prods_merged['prices'].max()
# Out:
# 25.0

# %%
#exporting the new  data
df_cust_ords_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_merged_with_category_with_flag_customer.pkl'))
